# %% [markdown]
# Hello Nicholas!
#
# I'm happy to review your project today.
#
# When I will see mistake at the first time, I will just point it out. I let you find it and fix it by yourself. I'm trying to prepare you to work as an Data Analyst. SO, at a real job, your team lead will do the same. But if you can't handle this task yet, I will give you a more accurate hint at the next iteration.
#
# You will find my comments below - **please do not move, modify or delete them**.
#
# You can find my comments in green, yellow or red boxes like this:
#
#
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Success. Everything is done succesfully.
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Remarks. Some recommendations.
# </div>
#
#
# <div class="alert alert-block alert-danger">
#
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
#
# Needs fixing. The block requires some corrections. Work can't be accepted with the red comments.
# </div>
#
#
# You can answer me by using this:
#
# <div class="alert alert-block alert-info">
# <b>Student answer. Hello, I need help with this assignment. I need some help with Project 6. Particularly the starting portion with SQL. There appears to be a gap in  the data needed that is not specified between the URL request and the cabs, trips data. The rest of the steps are fine. Looking forward to your help! </b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# Nicholas, thank you for sending your project. Unfortunately, there is a small problem: we have an error in the cell 6. Currently, the project cannot run automatically. Please check your code and use "Kernel > Restart & Run All" before sending the project.
#
# Waiting! :)
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Student answer. Hello, I need help with this assignment. I need some help with Project 6. Particularly the starting portion with SQL. There appears to be a gap in  the data needed that is not specified between the URL request and the cabs, trips data. The rest of the steps are fine. Looking forward to your help! </b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# Nicholas, we need to use SQLalchemy and other features from our theory course.
#
# Please check theory course and do not hesitate to ask your tutor for help.
#
# Good luck!
#
# </div>
#
#
# <div class="alert alert-block alert-danger">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# Nicholas, unfortunately I don't see any changesю Please check the brief before doing the project. It says what files you need to work with and what to do.
#
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Hello Solved in previous tasks for this Sprint. I visited office hours and he recommended leaving this comment so that the reviewer can skip past Sections 2 and 3 of this workbook entirely and continue the review of Python code. Thanks! </b> <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# Nicholas, unfortunately, I cannot skip anything. The project should run automatically. We need to use "Kernel > Restart & Run All". If we do not need parts/cells you should comment or drop them.
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# This is not possible. The data being called on in Steps 2 and 3 were from the Sprint 6 Chapter 6 Task: Working with Databases. Is even says in the task instruction that sections 2 and 3 have been completed. To avoid the error, I have removed them from this submission per the instructions to drop them. <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# Nicholas, please be attentive. We need to use the correct paths. Now paths are incorrect. Please use paths from the brief.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# I am not having this issue. Can you please be more specific? Mine were called moved_project_sql_result_01, moved_project_sql_result_04, and moved_project_sql_result_07 at the time of the download and last time I checked. They are running finely now. Can you please review the work. I am a week behind now. <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# You used your local paths. We need to use our paths for the server. Please check the brief, we have them there.</div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# Yes, I did. Can you be more clear on what and where the brief is and how to access the server? The tutor did not mention or recommend this.
#
# The brief does not have any information on accessing a server beyond the weather datasets which do not include cabs and trips. Again, this part of the assignment was completed in the task already so I removed it per their previous recommendation. Even there it did not utilize an explicit connection to a server. The data was just there when called on in SQL. Why is SQLAlchemy being called on? This seems extremely out of scope given the instruction from this section's chapters. <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# We  have correct paths in the brief. </div>

# %% [markdown]
# <div class="alert alert-block alert-info"> I used the same method taught in the lesson to pull in URLs from the brief. Everything should work for your review now.
#
# <a class="tocSkip"></a>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Overall reviewer's comment</b> <a class="tocSkip"></a>
#
# Nicholas, thank you for your corrections! Now I can see your project. And you've done a really good job on it! You write a clear code, and plot a good graphs. Thank you for the additional graphs and conclusions.
#
# <span class="text-danger">There are few things that need to be corrected in your project. They're mostly minor issues that are easy to fix. Could you check my comments?  Do not hesitate to ask your tutor for help, if you have any problems!</span>
#
#
# Waiting for the new version!
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Overall reviewer's comment.V.2.</b> <a class="tocSkip"></a>
#
# Hello Nicholas! Thank you for your corrections!
#
# Your project has been accepted, congratulations!
#
# Keep up the good work, and good luck on the next sprint! :)
#
#
#
# </div>

# %% [markdown]
# # Project description
#
# You're working as an analyst for Zuber, a new ride-sharing company that's launching in Chicago. Your task is to find patterns in the available information. You want to understand passenger preferences and the impact of external factors on rides.
#
# Working with a database, you'll analyze data from competitors and test a hypothesis about the impact of weather on ride frequency.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Great that we have a title and a description of the project</div>

# %% [markdown]
# ## Initialization
#
# ### Write a code to parse the data on weather in Chicago in November 2017 from the website: https://practicum-content.s3.us-west-1.amazonaws.com/data-analyst-eng/moved_chicago_weather_2017.html

# %%
pip install bokeh
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 66.9 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.0/305.0 kB 25.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.9/83.9 kB 12.2 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tabulate
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import pandas as pd
import bokeh
import scipy
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tabulate

# %% [markdown]
# ## Exploratory data analysis in Python
#
# In addition to the data you recovered in previous tasks, you have a second file. You now have these two CSVs:
#
#      •	/datasets/moved_project_sql_result_01.csv. It contains the following data:
#           o	company_name: taxi company name
#           o	trips_amount: the number of rides for each taxi company on November 15-16, 2017.
#
#      •	/datasets/moved_project_sql_result_04.csv. It contains the following data:
#           o	dropoff_location_name: Chicago neighborhoods where rides ended
#           o	average_trips: the average number of rides that ended in each neighborhood in November 2017.

# %% [markdown]
# ### Import the files

# %%
try:
    # URL 1: Trips
    url_trips = 'https://practicum-content.s3.us-west-1.amazonaws.com/learning-materials/data-analyst-eng/moved_project_sql_result_01.csv'
    df_trips = pd.read_csv(url_trips)

    # URL 2: Ohare Loop
    url_ohare_loop = 'https://practicum-content.s3.us-west-1.amazonaws.com/learning-materials/data-analyst-eng/moved_project_sql_result_04.csv'
    df_ohare_loop = pd.read_csv(url_ohare_loop)

    # URL 3: Dropoff
    url_dropoff = 'https://practicum-content.s3.us-west-1.amazonaws.com/learning-materials/data-analyst-eng/moved_project_sql_result_07.csv'
    df_dropoff = pd.read_csv(url_dropoff)

    # Print the DataFrames
    print(df_trips)
    print(df_ohare_loop)
    print(df_dropoff)

except FileNotFoundError:
    print("One or more CSV files not found. Please check file paths.")
# Out:
#                                  company_name  trips_amount
# 0                                   Flash Cab         19558
# 1                   Taxi Affiliation Services         11422
# 2                            Medallion Leasin         10367
# 3                                  Yellow Cab          9888
# 4             Taxi Affiliation Service Yellow          9299
# ..                                        ...           ...
# 59               4053 - 40193 Adwar H. Nikola             7
# 60                    2733 - 74600 Benny Jona             7
# 61              5874 - 73628 Sergey Cab Corp.             5
# 62  2241 - 44667 - Felman Corp, Manuel Alonso             3
# 63                3556 - 36214 RC Andrews Cab             2
#
# [64 rows x 2 columns]
#    dropoff_location_name  average_trips
# 0                   Loop   10727.466667
# 1            River North    9523.666667
# 2          Streeterville    6664.666667
# 3              West Loop    5163.666667
# ...

# %% [markdown]
# Comment: Here I decided to write a function that produces an error message for two reasons. I've improved my quality control before processing, but there still seem to be some issues downstream. I was also working in VSCode, so I had to upload the files to this cloud environment to read them into the dataframes.

# %% [markdown]
# ### Study the data they contain

# %%
# Check data structure in the fastest way
df_trips.info()
df_dropoff.info()
df_ohare_loop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   object
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 25.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
# ...

# %% [markdown]
# Comment: This is my way of extracting the information needed to configure my schema, workflows, and other diagrams, as well as anticipate incongruous df lengths. This also helps me track type transformations and dataframe changes.

# %%
# Rename the column "average_trips" to "number_of_trips"
df_ohare_loop = df_ohare_loop.rename(columns={'average_trips': 'number_of_trips'})

# %% [markdown]
# Comment: I decided to change the name of average trips because the metric did not make sense over a two-day period. It looked more like a count in the original csv.

# %%
# Quality assurance (QA) check to identify any irregularities in the datasets

def check_values(df):
    print(f"Checking {df.shape[0]} rows and {df.shape[1]} columns in DataFrame...")
    
    # Count zeros
    zero_count = (df == 0).sum().sum()
    print(f"Zeros found: {zero_count}")
    
    # Count null/nan an inf/-inf
    df_inf = df.replace([np.inf, -np.inf], np.nan)
    nan_count = df_inf.isnull().sum().sum()
    print(f"Null/NaN values found: {nan_count}")

check_values(df_trips)
check_values(df_dropoff)
check_values(df_ohare_loop)
# Out:
# Checking 64 rows and 2 columns in DataFrame...
# Zeros found: 0
# Null/NaN values found: 0
# Checking 1068 rows and 3 columns in DataFrame...
# Zeros found: 6
# Null/NaN values found: 0
# Checking 94 rows and 2 columns in DataFrame...
# Zeros found: 0
# Null/NaN values found: 0

# %% [markdown]
# Comment: I added a QA step here to anticipate the most common irregularities in dataframes or lists/columns. Inf/-inf was difficult to detect at first, but came into play in the video games mission. I still haven't found the reason why these appear.

# %%
# Remove rows where zeros were found to avoid any downstream processing issues
df_dropoff = df_dropoff[(df_dropoff != 0).all(axis=1)]

# %% [markdown]
# Comment: Here I decided to remove the rows with 0s because they represent about 0.5% of the data which I consider weak in this case.

# %%
# Split the “start_ts” column into “date” and “time” columns
df_dropoff[['date', 'time']] = df_dropoff['start_ts'].str.split(' ', expand=True)

# You now have your DataFrame with separate “date” and “time” columns.
print(df_dropoff.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1067
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1062 non-null   object
#  1   weather_conditions  1062 non-null   object
#  2   duration_seconds    1062 non-null   float64
#  3   date                1062 non-null   object
#  4   time                1062 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 49.8+ KB
# None

# %% [markdown]
# Comment: Here I am splitting the data frame ['start_ts'] into separate additional columns in anticipation of stratifying the data by time of day ['time'] or perhaps day of month ['date'].

# %% [markdown]
# ### Make sure the data types are correct

# %%
# Convert column 'start_ts' to datetime format
df_dropoff['start_ts'] = pd.to_datetime(df_dropoff['start_ts'])

# Extract the day from the 'start_ts' column
df_dropoff['day'] = df_dropoff['start_ts'].dt.day

print(df_dropoff.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1062 entries, 0 to 1067
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1062 non-null   datetime64[ns]
#  1   weather_conditions  1062 non-null   object
#  2   duration_seconds    1062 non-null   float64
#  3   date                1062 non-null   object
#  4   time                1062 non-null   object
#  5   day                 1062 non-null   int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 58.1+ KB
# None

# %% [markdown]
# Comment: Confirm that the data type for ['date'] is converted to an int value and assign an int 0 to 6 to ['day']

# %%
# Convert 'date' column to datetime format
df_dropoff['date'] = pd.to_datetime(df_dropoff['date'])

df_dropoff.dtypes
# Out:
# start_ts              datetime64[ns]
# weather_conditions            object
# duration_seconds             float64
# date                  datetime64[ns]
# time                          object
# day                            int64
# dtype: object

# %%
# assume df_trips is your dataframe and 'company_name' is the column with unwanted characters

df_trips['company_name'] = df_trips['company_name'].str.replace(r'\d{4} - \d{5}', '', regex=True)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Well done! We have our datasets, checked duplicates and missing value.
#
# </div>
#
#
# <div class="alert alert-block alert-warning">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# It would be informative to write a conclusion about the first part.
# </div>

# %% [markdown]
# Conclusion: There were initial challenges regarding the source of data in this section. This was resolved using the beautifulSoup extraction method from URLs which were not explicitly provided in the instruction. The data was read in the same was a when it stored locally. This is the first way that I had completed the assignment before moving to the JSO/SQL way. I tried a package called SQLite3 at first, but this resultingly was not needed. In terms of coding practices, I am trying to implement more operations to avoid repetitive blocks of code and improve reusability and quality control as demonstrated in the try/except block where the data is read in and the check_values function which attempts to address irregularities in the data upfront which are specifically zeros, null/NaN, and inf/-inf values. Next, I did a reviewed the output from the check values function and decided that the rows with zeros could be dropped because there were 6 out of the whole dataset which is very minimal. Then, I split the ['date'] column into new columns called ['time'] and ['day'] to use them as stratification factors later on and is part of the panda set of functions. Lastly here, this step was added after completing the pie charts in Step 3. The list of company names appeared to have a large number of companies who had a 'company_name' of '####-#####company_name' in the ['company_name'] column. To address this I used a string replace method which uses \d{} to identify the characters and replace them with a no space. The regrex parameter is to keep the context of the operation in terms of strings because the hashtags were digits.

# %% [markdown]
# ### Identify the top 10 neighborhoods in terms of dropouts

# %%
# Assuming df_ohare_loop is your DataFrame
df_ohare_loop = df_ohare_loop.sort_values(by='number_of_trips', ascending=False)

# Now df_ohare_loop is sorted by column 'average_trips' in descending order
print("The most popular taxi ride destinations in Chicago in November 2017 were:")
display(df_ohare_loop.head(10))
# Out:
# The most popular taxi ride destinations in Chicago in November 2017 were:
#   dropoff_location_name  number_of_trips
# 0                  Loop     10727.466667
# 1           River North      9523.666667
# 2         Streeterville      6664.666667
# 3             West Loop      5163.666667
# 4                O'Hare      2546.900000
# 5             Lake View      2420.966667
# 6            Grant Park      2068.533333
# 7         Museum Campus      1510.000000
# 8            Gold Coast      1364.233333
# 9    Sheffield & DePaul      1259.766667

# %%
# Assuming df_ohare_loop is your DataFrame

# Calculate the 50th percentile of trips_amount
ohare_loop_number_75th_percentile = np.percentile(df_ohare_loop['number_of_trips'], 75)

# Filter the database to only include companies with trip amounts above the 50th percentile
df_ohare_loop_filtered = df_ohare_loop[df_ohare_loop['number_of_trips'] > ohare_loop_number_75th_percentile]


# Create the horizontal bar chart using seaborn
sns.barplot(x="number_of_trips", y="dropoff_location_name", data=df_ohare_loop_filtered, palette="Dark2")  # Reversed order for horizontal bars
plt.xlabel("Amount of Travel")
plt.ylabel("Company Name")
plt.title("Top Dropoff Locations by Number of Trips (Above 75th Percentile)")

# Set the X axis limit (modify as needed)
plt.xlim(0, 25000)  # Adjust based on your data

# Add data labels with formatting
for i, (company, trips) in enumerate(zip(df_ohare_loop_filtered['dropoff_location_name'], df_ohare_loop_filtered['number_of_trips'])):
    plt.text(trips + 100, i, f"{trips:,.0f}", ha='left', va='center')  # Use comma separator for readability

plt.show()

# %%
# Create the pie chart
plt.figure(figsize=(10, 8))  # Lengthen the frame
plt.pie(df_ohare_loop_filtered['number_of_trips'], labels=df_ohare_loop_filtered['dropoff_location_name'], autopct='%1.1f%%', startangle=90)
plt.title('Travel market distribution by company (above 50th percentile)')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Thank you! Perhaps, those neighborhoods are in city center or they have some popular places. :)
#
# </div>

# %% [markdown]
# Conclusion: This analysis identified a list of top Zuber destinations in Chicago for passengers starting at the airport and represents both visitors/tourists and those returning home. At first, the data was visualized in its entirety which showed a large map with a large number of neighborhoods well below 20 trips. This added a lot of noise and detracted from the readibility of the graph. I then adjusted to the top 50th percentile, then 75th percentile which was the right level of stratification as shown above. The top four destinations appear to account for about 50% of the total destinations indicating their popularity for the city. I will develop a better function to get exact proportions from the sample on the next occasion.

# %% [markdown]
# ### Make charts: taxi companies and number of trips, top 10 neighborhoods by number of drop-offs

# %%
# Taxi companies first visualization(Horizontal Bar Chart using ['company_name'] and sum of ['trips_amount'] )

# Calculate the 50th percentile of trips_amount
trips_amount_50th_percentile = np.percentile(df_trips['trips_amount'], 50)

# Filter the database to only include companies with trip amounts above the 50th percentile
df_trips_filtered = df_trips[df_trips['trips_amount'] > trips_amount_50th_percentile]

# Sort data frame by “trips_amount” in descending order
df_trips_sorted = df_trips_filtered.groupby('company_name')['trips_amount'].sum().reset_index().sort_values('trips_amount', ascending=False)

# Create the horizontal bar chart using seaborn
plt.figure(figsize=(10, 15))  # Lengthen the frame
sns.barplot(x='trips_amount', y='company_name', data=df_trips_sorted, palette="Dark2")
plt.xlabel('Amount of travel')
plt.ylabel('Company Name')
plt.title('Top Companies by Travel Amount (Above 50th Percentile)')

# Set the X axis limit to 25000
plt.xlim(0, 25000)

# Add data labels
for i, (company, trips) in enumerate(zip(df_trips_sorted['company_name'], df_trips_sorted['trips_amount'])):
    plt.text(trips + 100, i, f'{trips:.0f}', ha='left', va='center')

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Very good! Thank you for sorted values for graph. It makes it more understandble.
#
# Yes, flash cab is a best here. Perhaps, because of Flash or number of trips. :)
# </div>

# %%
import matplotlib.pyplot as plt

# Calculate the 50th percentile of trips_amount
trips_amount_75th_percentile = np.percentile(df_trips['trips_amount'], 75)

# Filter the database to only include companies with trip amounts above the 50th percentile.
df_trips_filtered2 = df_trips[df_trips['trips_amount'] > trips_amount_75th_percentile]

# Sort data frame by “trips_amount” in descending order
df_trips_sorted2 = df_trips_filtered2.groupby('company_name')['trips_amount'].sum().reset_index().sort_values('trips_amount', ascending=False)

# Create the pie chart
plt.figure(figsize=(10, 8))  # Lengthen the frame
plt.pie(df_trips_sorted2['trips_amount'], labels=df_trips_sorted2['company_name'], autopct='%1.1f%%', startangle=90)
plt.title('Travel market distribution by company (above 50th percentile)')

plt.show()

# %% [markdown]
# Comment: I plotted the dataset on the barplot first, then I had to reduce the dataset, so I went with 50% to get a nice distribution. There were also many companies < 50 trips, so it was incredibly difficult to read and would be revisited later with box plots. I then added a pie chart for a market share type visualization of the top 20% of companies in terms of journey, which adds better dimension to the raw values ​​in the bar chart.
#
# Insight: So we see that the top 6 or 7 companies take 50% of the ride share during the two-day period. Flash Cab is a leader with a much larger share of trips, followed by Taxi Affiliation Services and Medallion Leasin. The following three companies are fundamentally related. We can also recognize that there are a large number of companies in the local market.

# %%
# Create a boxplot of the full dataset
plt.figure(figsize=(8, 6))
sns.boxplot(x='trips_amount', data=df_trips, whis=[5, 95])
plt.title('Distribution of Trips Amount')
plt.xlabel('Trips Amount')
plt.ylabel('')

# Add a horizontal line at the 50th percentile
trips_amount_50th_percentile = np.percentile(df_trips['trips_amount'], 50)
plt.axvline(trips_amount_50th_percentile, color='r', linestyle='--', label='50th Percentile')

plt.legend()
plt.show()

# %% [markdown]
# Comment: I started with statistical analysis by first visualizing the data. I was drawn to this visualization because I noticed that a large portion of companies are at the lower end of the trips_amount metric.
#
# Overview: As we can see, market leaders are outliers and the concept of market share is not well understood due to the significant weight of companies below the 75th percentile. No other ideas here – mostly exploratory.

# %%
print(tabulate.tabulate([df_trips['trips_amount'].describe().values], 
                         headers=df_trips['trips_amount'].describe().index, 
                         tablefmt='psql'))
# Out:
# +---------+---------+---------+-------+-------+-------+--------+-------+
# |   count |    mean |     std |   min |   25% |   50% |    75% |   max |
# |---------+---------+---------+-------+-------+-------+--------+-------|
# |      64 | 2145.48 | 3812.31 |     2 | 20.75 | 178.5 | 2106.5 | 19558 |
# +---------+---------+---------+-------+-------+-------+--------+-------+

# %% [markdown]
# Comment: Added a descriptive statistics model. I found a package called tabulate which is ok. I like it even better than unstructured output.
#
# Outlook: described in the table.

# %%
# Number of trips first visualization (Pie Chart of proportion of rides by weather_condtion through a count of ['weather_conditions'])

# Count the number of rides by weather condition
weather_counts = df_dropoff['weather_conditions'].value_counts()

# Create a pie chart
plt.figure(figsize=(8, 6))
plt.pie(weather_counts, labels=weather_counts.index, autopct='%1.1f%%', colors=['orange', 'lightgrey'], explode=[0., 0.2], shadow = True, startangle=45)
plt.title('Proportion of trips depending on weather conditions')
plt.show()

# %%
from bokeh.models import ColumnDataSource, Whisker, Span
from bokeh.plotting import figure, show
from bokeh.transform import factor_cmap, jitter
from bokeh.io import output_notebook

output_notebook()

classes = list(sorted(df_dropoff["weather_conditions"].unique()))

p = figure(height=400, x_range=classes, background_fill_color="#efefef",
           title="Weather Condition vs Trip Duration with quantile ranges")
p.xgrid.grid_line_color = None

g = df_dropoff.groupby("weather_conditions")
upper = g.duration_seconds.quantile(0.75)
lower = g.duration_seconds.quantile(0.25)
median = g.duration_seconds.quantile(0.5)
min_val = df_dropoff.duration_seconds.quantile(1.0)
max_val = df_dropoff.duration_seconds.quantile(0.0)
median_val = df_dropoff.duration_seconds.median()

source = ColumnDataSource(data=dict(base=classes, upper=upper, lower=lower, median=median))

error = Whisker(base="base", upper="upper", lower="lower", source=source,
                level="annotation", line_width=2)
error.upper_head.size=20
error.lower_head.size=20
p.add_layout(error)

# Add indicators for 0%, 50%, and 100%
min_indicator = Span(location=min_val, dimension='width', line_color='red', line_width=2)
p.add_layout(min_indicator)

median_indicator = Span(location=median_val, dimension='width', line_color='green', line_width=2)
p.add_layout(median_indicator)

max_indicator = Span(location=max_val, dimension='width', line_color='blue', line_width=2)
p.add_layout(max_indicator)

p.scatter(jitter("weather_conditions", 0.3, range=p.x_range), "duration_seconds", source=df_dropoff,
          alpha=0.5, size=13, line_color="white",
          color=factor_cmap("weather_conditions", "Light7", classes))

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="de7e0cbb-24a3-4c00-b7c5-8d4c7a6e8fcc">Loading BokehJS ...</span>
#     </div>
#   <div id="c2b0b541-8a2d-4118-83a9-ab5637928821" data-root-id="p1001" style="display: contents;"></div>

# %% [markdown]
# Comment: I needed a more powerful set of visualizations for dimension and attribute analysis. So I've identified a few that I'm going to work on. I still need help deploying the bokeh (possibly viola) in Render if you have any help let me know. I would appreciate if these apps were kept a little secret, as they are a competitive advantage for us job seekers. I also need to go back and create the simplified model training dashboard that was shown earlier. I am developing a forecasting application.
#
# Insight: We see that at first glance there is no visually identifiable difference in travel time in seconds on days when the weather was either rainy ("bad") or sunny ("good").

# %%
print(df_dropoff.head())
# Out:
#              start_ts weather_conditions  duration_seconds       date  \
# 0 2017-11-25 16:00:00               Good            2410.0 2017-11-25
# 1 2017-11-25 14:00:00               Good            1920.0 2017-11-25
# 2 2017-11-25 12:00:00               Good            1543.0 2017-11-25
# 3 2017-11-04 10:00:00               Good            2512.0 2017-11-04
# 4 2017-11-11 07:00:00               Good            1440.0 2017-11-11
#
#        time  day
# 0  16:00:00   25
# 1  14:00:00   25
# 2  12:00:00   25
# 3  10:00:00    4
# 4  07:00:00   11

# %%
# Comparison of three dimensions (Bokeh scatter with markers = ['weather_conditions'], x = ['duration_seconds'], y = ['time'])
#https://docs.bokeh.org/en/latest/docs/examples/basic/data/transform_markers.html

from bokeh.plotting import figure, show
from bokeh.transform import factor_cmap, factor_mark
from bokeh.transform import factor_cmap, jitter
from bokeh.io import output_notebook

output_notebook()

# Create legend groups, markers, and color maps based on unique weather conditions
SPECIES = df_dropoff['weather_conditions'].unique()  # Get unique weather conditions
MARKERS = ['hex', 'circle_x'] * (len(SPECIES) // 2 + 1)  # Assign markers cyclically

# Convert time column to datetime format
df_dropoff['time'] = pd.to_datetime(df_dropoff['time'], format='%H:%M:%S')

p = figure(title="Weather Conditions", background_fill_color="#fafafa")
p.xaxis.axis_label = 'Duration (seconds)'
p.yaxis.axis_label = 'Start Time'

p.scatter(x="duration_seconds", y="time", source=df_dropoff,
          legend_group="weather_conditions", fill_alpha=0.3, size=4,
          marker=factor_mark('weather_conditions', MARKERS, SPECIES),
          color=factor_cmap('weather_conditions', 'Category10_3', SPECIES))

p.legend.location = "top_left"
p.legend.title = "Weather Conditions"

show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="c8baefb8-f99d-44f0-8205-93e2d4518353">Loading BokehJS ...</span>
#     </div>
#   <div id="e3acd975-49c4-4a57-ba2b-cea2cf0bf1cc" data-root-id="p1069" style="display: contents;"></div>

# %% [markdown]
# Comment: I'm moving towards Principal Component Analysis (PCA) here by asking if a difference can be observed in two data sets assuming travel time is an independent variable (someone needed to go somewhere that day) versus the time they chose to leave or set that appointment.
#
# Overview: Three interesting observations are: (1) the data is correct, positively skewed, (2) there is a visual indication that as trip durations lengthen, departure times are later in the day (positive slope line), and (3) trips on bad days appear to have a later departure time.

# %%
from bokeh.models import Band, ColumnDataSource
from bokeh.plotting import figure, output_notebook, show
import pandas as pd

output_notebook()

# Create some data from your DataFrame
x = df_dropoff['duration_seconds']
y = df_dropoff['time']

# Convert time column to datetime format (as discussed earlier)
y = pd.to_datetime(y, format='%H:%M:%S')

# Create a new DataFrame with the data
df = pd.DataFrame(data=dict(x=x, y=y)).sort_values(by="x")

# Calculate rolling mean and standard deviation
df['y_mean'] = df['x'].rolling(window=300).mean()
df['y_std'] = df['x'].rolling(window=300).std()

# Calculate lower and upper bounds for the band
df["lower"] = df['y_mean'] - df['y_std']
df["upper"] = df['y_mean'] + df['y_std']

# Create a ColumnDataSource from the DataFrame
source = ColumnDataSource(df)

# Create the figure
p = figure(tools="", toolbar_location=None, x_axis_label='Duration (seconds)', y_axis_label='Start Time')
p.title.text = "Rolling Standard Deviation"
p.xgrid.grid_line_color=None
p.ygrid.grid_line_alpha=0.5

# Add scatter plot
p.scatter(x="x", y="y", color="blue", marker="dot", size=10, alpha=0.4, source=source)

# Add line plot for rolling mean
p.line("x", "y_mean", line_dash=(10, 7), line_width=2, source=source)

# Add band for rolling standard deviation
band = Band(base="x", lower="lower", upper="upper", source=source,
            fill_alpha=0.3, fill_color="yellow", line_color="black")
p.add_layout(band)

# Show the plot
show(p)
# Out:
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="d2b43e1c-6bab-4c73-872d-bde17dd9d2f5">Loading BokehJS ...</span>
#     </div>
#   <div id="b93c4015-7b26-4408-94b6-3dfda7831499" data-root-id="p1128" style="display: contents;"></div>

# %%
# Top 10 neighborhoods by number of deposits first viewing 
# Sort the DataFrame by “average_trips” in descending order

# Convert 'average_trips' to int (assuming it's a float)
top_10_df = df_ohare_loop.copy()  # Create a copy (optional)
top_10_df['number_of_trips'] = top_10_df['number_of_trips'].astype(int)

# Get the first 10 lines (neighborhoods)
top_10_df = top_10_df.sort_values(by='number_of_trips', ascending=False).head(10)

display(top_10_df)
df_ohare_loop.describe()
# Out:
#   dropoff_location_name  number_of_trips
# 0                  Loop            10727
# 1           River North             9523
# 2         Streeterville             6664
# 3             West Loop             5163
# 4                O'Hare             2546
# 5             Lake View             2420
# 6            Grant Park             2068
# 7         Museum Campus             1510
# 8            Gold Coast             1364
# 9    Sheffield & DePaul             1259
#        number_of_trips
# count        94.000000
# mean        599.953728
# std        1714.591098
# min           1.800000
# 25%          14.266667
# 50%          52.016667
# 75%         298.858333
# max       10727.466667

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Thank you for the additional graphs! It was very informative.
# </div>
#
# <div class="alert alert-block alert-danger">
# <s><b>Reviewer's comment</b> <a class="tocSkip"></a>
#
# Please note that there is an error in cell 22: "AttributeError: 'DataFrame' object has no attribute 'y_mean'."
#
# Could you kindly check your code? Once this is resolved, I will be able to continue reviewing your project.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info"> The output visualization was not insightful and showed two lines on opposite ends of the y-axis instead of a scatter. I could not resolve the issue without significantly transforming the data which was not needed for this assignment. I'm leaving the visualization in to show you what I am describing, but no insights can be gleaned. I want to add this plot to my portfolio, so I will need to incorporate it again at a later time.<a class="tocSkip"></a> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Great! Thank you for your corrections!
# </div>

# %% [markdown]
# ### Draw conclusions based on each graph and explain the results

# %% [markdown]
# Insights: Analytics seeks to extract insights from data sets that aren’t so related after all. For ecample, we get sorted values​and descriptive statistics for the different metrics but the datasets answer very different questions. For example, journey duration and departure time reflect consumer behavior, market leaders are useful for this market perspective and a distant consumption perspective. Finally, the destination part is useful for determining user types, but it is still difficult to characterize, especially in urban areas.

# %% [markdown]
# ## Test the hypothesis in Python
#
#      • /datasets/project_sql_result_07.csv — the result of the last query. It contains data on trips from the Loop to O'Hare International Airport. Remember, these are the table field values:
#
#           o	start_ts
#           o	pickup date and time
#           o	weather_conditions
#           o	weather conditions at the moment the ride started
#           o	duration_seconds
#           o	ride duration in seconds

# %% [markdown]
# ### Test the hypothesis:
#
# Zero: The average travel time from the Loop to O'Hare International Airport changes on rainy Saturdays.
#
# Alternative: The average travel time from the Loop to O'Hare International Airport does not change on rainy Saturdays.
#
# And the hypothesis test we should use is: t-test of proportion for one sample

# %%
from scipy.stats import ttest_ind

# Add a day of the week column
df_dropoff['day_of_week'] = df_dropoff['date'].dt.dayofweek

# Create a binary column indicating whether it's a Saturday
df_dropoff['is_saturday'] = df_dropoff['day_of_week'] == 5

# Create a binary column indicating whether the weather is “Bad” (1) or “Good” (0)
df_dropoff['bad_weather'] = np.where(df_dropoff['weather_conditions'] == 'Bad', 1, 0)

# Divide data into rainy Saturdays and other days
rainy_saturdays = df_dropoff[(df_dropoff['is_saturday'] == True) & (df_dropoff['bad_weather'] == 1)]['duration_seconds']
other_days = df_dropoff[(df_dropoff['is_saturday'] != True) | (df_dropoff['bad_weather'] == 0)]['duration_seconds']

print(rainy_saturdays.shape, other_days.shape)
# Out:
# (180,) (882,)

# %%
# Perform a two-sample t-test
t_stat, p_val = ttest_ind(rainy_saturdays, other_days)

print(f"t-statistic: {t_stat:.2f}, p-value: {p_val:.4f}")

# Interpret the results
if p_val < 0.05:
    print("Reject the null hypothesis: the average travel duration on rainy Saturdays is significantly different from other days.")
else:
    print("Do not reject the null hypothesis: the average travel time on rainy Saturdays is not significantly different from other days.")
# Out:
# t-statistic: 6.84, p-value: 0.0000
# Reject the null hypothesis: the average travel duration on rainy Saturdays is significantly different from other days.

# %%
sns.boxplot(x="day_of_week", y="duration_seconds", hue="weather_conditions", data=df_dropoff)
plt.title("Distribution of duration_seconds by day_of_week and weather_condition")
plt.show()

# %%
sns.kdeplot(x="duration_seconds", hue="weather_conditions", data=df_dropoff, fill=True)
plt.title("Density plots of duration_seconds by climate_condition and day_of-week")
plt.show()

# %%
from scipy.stats import mannwhitneyu

# Perform the nonparametric test
u_stat, p_val = mannwhitneyu(rainy_saturdays, other_days)

# Format output
print(f"Mann-Whitney U statistic: {u_stat:.2f}")
print(f"p-value: {p_val:.4f}")
# Out:
# Mann-Whitney U statistic: 107113.50
# p-value: 0.0000

# %% [markdown]
# #### How did you form the null and alternative hypotheses? What criterion did you use to test the hypotheses and why? How will my project be evaluated?

# %% [markdown]
# Comment: Here, the challenge was to reclassify the data and ensure its readability. So the date needed to be converted to a day of the week, then an index for the day, then some separation for the weather condition, so I used a boolean value for good or bad. I then ran the t-test and got a p-value of 0.0, which was fishy, ​​so I decided to visualize the data. The boxplot showed no real difference, then I applied a non-parametric statistical test because I remembered the data from the previous graph was skewed. The result was also a p-value of 0.0.
#
# Overview: Travel times on rainy Saturdays in November are very different from those on other days of the same month.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Great, we choosed correct alpha and test.
#
# And yes, you are right. The average duration of rides on sunny and rainy days differs, and the duration of rides on bad weather days is longer than on good weather days.
#
# Very good that we check it by test. It gives us the total picture.
# </div>

# %% [markdown]
# ## General Conclusion

# %% [markdown]
# The lessons learned from taxi rides in Chicago in November 2017 were difficult and disparate, but we identified the top businesses, the most popular neighborhoods, quantified the number of rides, duration and start time, then segmented into depending on the weather variable.
#
# This mission was useful and stimulating. I had big problems with the bokeh package due to its complex parameters that appear to intersect with scipy. I was unable to deploy it to Render. I will have to overcome these obstacle in the future. I like working with new visualizations because they are more insightful. Statistical tests are very useful in strengthening my test selection and interpretation of results which are based on lean six sigma principles.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Reviewer's comment. V.2.</b> <a class="tocSkip"></a>
#
# Well done! Thank you for the final conclusion!
# </div>
